# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# 图像读取，显示，保存
# cv2.imread()
# cv2.imshow()
# cv2.imwrite()

# %%
# %matplotlib inline

# %%
img = cv2.imread("../images/test.jpg", -1)

# %% [raw]
# 获取像素点值，结果对应的是BGR，其中坐标对应的是行，列，所以实际上是(y, x)

# %%
src = cv2.imread("airplane.bmp")
src = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
dst = cv2.equalizeHist(src)
plt.imshow(src)

# %%
plt.imshow(dst)

# %% [raw]
# 获取图片属性：行数、列数和通道数

# %%
print(img.shape)

# %% [raw]
# 获取图像数据类型

# %%
print(img.dtype)

# %% [raw]
# 获取图像总像素数

# %%
print(img.size)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_gray)

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
plt.axis("off")
plt.show()

# %%
b,g,r = cv2.split(img)
img3 = cv2.merge((r,g,b))
plt.imshow(img3)

# %%
def translate(src, translate_x, translate_y):
    src_h, src_w = src.shape[:2]
    dst = np.zeros(src.shape, dtype=np.uint8)
    for row in range(src_h):
        for col in range(src_w):
            h = int(row-translate_y)
            w = int(col-translate_x)
            if h<src_h and h>=0 and w<src_w and w>=0:
                dst[row][col] = src[h][w]
    return dst
new_image = translate(img3, 200, 100)
# plt.axis("off")
plt.imshow(new_image)
# plt.show()
